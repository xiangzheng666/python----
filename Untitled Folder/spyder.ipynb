# %%
import requests 
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
r=requests.get(r'http://www.jobbole.com/')

# %%
r.status_code
# Out:
# 200

# %%
r.encoding=r.apparent_encoding

# %%
soup=BeautifulSoup(r.text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="no-transform " http-equiv="Cache-Control">
# <meta content="no-siteapp" http-equiv="Cache-Control"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>伯乐财经在线网_财经股票证券门户网站 _ 伯乐财经网</title>
# <meta content="伯乐财经网,伯乐在线,股票,公司,财经,理财,科技,消费" name="keywords"/>
# <meta content="伯乐财经在线网为用户提供国内外财经新闻资讯，涵盖股票、公司、财经、理财、科技、消费等频道，致力于打造最新最及时最全面的财经咨询平台。" name="description"/>
# <link href="/kaifadou/statics/v4/css/style.css" rel="stylesheet"/>
# <script src="/kaifadou/statics/v4/js/jquery-1.8.3.min.js" type="text/javascript"></script>
# <script src="/kaifadou/statics/v4/js/swiper-3.3.1.min.js" type="text/javascript"></script>
# <script language="javascript" type="text/javascript">
# 	showMobile("http://m.jobbole.com");
# </script>
# </meta></head>
# <body>
# <div class="mask"></div>
# <div class="header">
# <div id="top-bar">
# ...
